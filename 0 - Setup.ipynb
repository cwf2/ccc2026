# %% [markdown]
# ## Install package code and prerequisites

# %%
# %pip install -e .
# %pip install git+https://github.com/cwf2/uva_common
# Out:
# Obtaining file:///Users/chris/Documents/git/dices-project-container/ccc2026
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (2.5.0)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (3.0.3)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (1.9.0)
# Requirement already satisfied: scipy in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (1.18.0)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (3.11.0)
# Requirement already satisfied: seaborn in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (0.13.2)
# Requirement already satisfied: jupyter in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (1.1.1)
# Requirement already satisfied: ipywidgets in ./venv/lib/python3.12/site-packages (from ccc2026==0.1.0) (8.1.8)
# Collecting uva_common@ git+https://github.com/cwf2/uva_common (from ccc2026==0.1.0)
#   Cloning https://github.com/cwf2/uva_common to /private/var/folders/2x/rfhzgyjn2zq2wlzk_kn4th680000gn/T/pip-install-d4_o3_kc/uva-common_978402785e0c4a7ba46df1443c33bee2
#   Running command git clone --filter=blob:none --quiet https://github.com/cwf2/uva_common /private/var/folders/2x/rfhzgyjn2zq2wlzk_kn4th680000gn/T/pip-install-d4_o3_kc/uva-common_978402785e0c4a7ba46df1443c33bee2
#   Resolved https://github.com/cwf2/uva_common to commit 35c5728028d98a895256cf4af61e4888f74d2a94
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: lxml in ./venv/lib/python3.12/site-packages (from uva_common@ git+https://github.com/cwf2/uva_common->ccc2026==0.1.0) (6.1.1)
# Requirement already satisfied: gitpython in ./venv/lib/python3.12/site-packages (from uva_common@ git+https://github.com/cwf2/uva_common->ccc2026==0.1.0) (3.1.50)
# Requirement already satisfied: osfclient in ./venv/lib/python3.12/site-packages (from uva_common@ git+https://github.com/cwf2/uva_common->ccc2026==0.1.0) (0.0.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv/lib/python3.12/site-packages (from gitpython->uva_common@ git+https://github.com/cwf2/uva_common->ccc2026==0.1.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->uva_common@ git+https://github.com/cwf2/uva_common->ccc2026==0.1.0) (5.0.3)
# Requirement already satisfied: comm>=0.1.3 in ./venv/lib/python3.12/site-packages (from ipywidgets->ccc2026==0.1.0) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in ./venv/lib/python3.12/site-packages (from ipywidgets->ccc2026==0.1.0) (9.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./venv/lib/python3.12/site-packages (from ipywidgets->ccc2026==0.1.0) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./venv/lib/python3.12/site-packages (from ipywidgets->ccc2026==0.1.0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./venv/lib/python3.12/site-packages (from ipywidgets->ccc2026==0.1.0) (3.0.16)
# Requirement already satisfied: decorator>=5.1.0 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (3.0.52)
# Requirement already satisfied: psutil>=7 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in ./venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (0.6.3)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in ./venv/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.12/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (3.0.1)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->ccc2026==0.1.0) (0.2.3)
# Requirement already satisfied: notebook in ./venv/lib/python3.12/site-packages (from jupyter->ccc2026==0.1.0) (7.6.0)
# Requirement already satisfied: jupyter-console in ./venv/lib/python3.12/site-packages (from jupyter->ccc2026==0.1.0) (6.6.3)
# Requirement already satisfied: nbconvert in ./venv/lib/python3.12/site-packages (from jupyter->ccc2026==0.1.0) (7.17.1)
# Requirement already satisfied: ipykernel in ./venv/lib/python3.12/site-packages (from jupyter->ccc2026==0.1.0) (7.3.0)
# Requirement already satisfied: jupyterlab in ./venv/lib/python3.12/site-packages (from jupyter->ccc2026==0.1.0) (4.6.1)
# Requirement already satisfied: appnope>=0.1.2 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (1.8.21)
# Requirement already satisfied: jupyter-client>=8.9.0 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (5.9.1)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (1.7.2)
# Requirement already satisfied: packaging>=22 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (26.2)
# Requirement already satisfied: pyzmq>=25 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in ./venv/lib/python3.12/site-packages (from ipykernel->jupyter->ccc2026==0.1.0) (6.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter->ccc2026==0.1.0) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in ./venv/lib/python3.12/site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter->ccc2026==0.1.0) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.12/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter->ccc2026==0.1.0) (4.10.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel->jupyter->ccc2026==0.1.0) (1.17.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (3.1.6)
# Requirement already satisfied: jupyter-builder>=1.0.2 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (1.0.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in ./venv/lib/python3.12/site-packages (from jupyterlab->jupyter->ccc2026==0.1.0) (0.2.4)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->ccc2026==0.1.0) (4.14.1)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->ccc2026==0.1.0) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->ccc2026==0.1.0) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->ccc2026==0.1.0) (3.18)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (1.9.0)
# Requirement already satisfied: babel>=2.10 in ./venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in ./venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in ./venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (4.26.0)
# Requirement already satisfied: requests>=2.31 in ./venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in ./venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->ccc2026==0.1.0) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in ./venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (6.0.3)
# Requirement already satisfied: rfc3339-validator in ./venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (0.1.1)
# Requirement already satisfied: fqdn in ./venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (1.5.1)
# Requirement already satisfied: isoduration in ./venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (1.1.0)
# Requirement already satisfied: uri-template in ./venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.12/site-packages (from nbconvert->jupyter->ccc2026==0.1.0) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in ./venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->ccc2026==0.1.0) (6.4.0)
# Requirement already satisfied: defusedxml in ./venv/lib/python3.12/site-packages (from nbconvert->jupyter->ccc2026==0.1.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./venv/lib/python3.12/site-packages (from nbconvert->jupyter->ccc2026==0.1.0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./venv/lib/python3.12/site-packages (from nbconvert->jupyter->ccc2026==0.1.0) (3.3.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./venv/lib/python3.12/site-packages (from nbconvert->jupyter->ccc2026==0.1.0) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./venv/lib/python3.12/site-packages (from nbconvert->jupyter->ccc2026==0.1.0) (1.5.1)
# Requirement already satisfied: webencodings in ./venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->ccc2026==0.1.0) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in ./venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->ccc2026==0.1.0) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in ./venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->ccc2026==0.1.0) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in ./venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in ./venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (2.0.0)
# Requirement already satisfied: pycparser in ./venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in ./venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->ccc2026==0.1.0) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in ./venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (1.4.0)
# Requirement already satisfied: tzdata in ./venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->ccc2026==0.1.0) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.12/site-packages (from matplotlib->ccc2026==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.12/site-packages (from matplotlib->ccc2026==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.12/site-packages (from matplotlib->ccc2026==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib->ccc2026==0.1.0) (1.5.0)
# Requirement already satisfied: pillow>=9 in ./venv/lib/python3.12/site-packages (from matplotlib->ccc2026==0.1.0) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.12/site-packages (from matplotlib->ccc2026==0.1.0) (3.3.2)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from osfclient->uva_common@ git+https://github.com/cwf2/uva_common->ccc2026==0.1.0) (4.68.3)
# Requirement already satisfied: joblib>=1.4.0 in ./venv/lib/python3.12/site-packages (from scikit-learn->ccc2026==0.1.0) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in ./venv/lib/python3.12/site-packages (from scikit-learn->ccc2026==0.1.0) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in ./venv/lib/python3.12/site-packages (from scikit-learn->ccc2026==0.1.0) (3.6.0)
# Building wheels for collected packages: ccc2026
#   Building editable for ccc2026 (pyproject.toml) ... done
#   Created wheel for ccc2026: filename=ccc2026-0.1.0-0.editable-py3-none-any.whl size=1358 sha256=de1f11a355f29c6a39da968ec2e7e35e229315849d796185bbae7c96c92e07ba
#   Stored in directory: /private/var/folders/2x/rfhzgyjn2zq2wlzk_kn4th680000gn/T/pip-ephem-wheel-cache-rasp1l3k/wheels/7b/34/29/d822a90f3df39c7711184c941b94a997842a081ab63b0fc754
# Successfully built ccc2026
# Installing collected packages: ccc2026
#   Attempting uninstall: ccc2026
#     Found existing installation: ccc2026 0.1.0
#     Uninstalling ccc2026-0.1.0:
#       Successfully uninstalled ccc2026-0.1.0
# Successfully installed ccc2026-0.1.0
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/cwf2/uva_common
#   Cloning https://github.com/cwf2/uva_common to /private/var/folders/2x/rfhzgyjn2zq2wlzk_kn4th680000gn/T/pip-req-build-n2glvgdg
#   Running command git clone --filter=blob:none --quiet https://github.com/cwf2/uva_common /private/var/folders/2x/rfhzgyjn2zq2wlzk_kn4th680000gn/T/pip-req-build-n2glvgdg
#   Resolved https://github.com/cwf2/uva_common to commit 35c5728028d98a895256cf4af61e4888f74d2a94
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: lxml in ./venv/lib/python3.12/site-packages (from uva_common==0.1.0) (6.1.1)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (from uva_common==0.1.0) (3.0.3)
# Requirement already satisfied: gitpython in ./venv/lib/python3.12/site-packages (from uva_common==0.1.0) (3.1.50)
# Requirement already satisfied: osfclient in ./venv/lib/python3.12/site-packages (from uva_common==0.1.0) (0.0.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv/lib/python3.12/site-packages (from gitpython->uva_common==0.1.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->uva_common==0.1.0) (5.0.3)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from osfclient->uva_common==0.1.0) (2.34.2)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from osfclient->uva_common==0.1.0) (4.68.3)
# Requirement already satisfied: six in ./venv/lib/python3.12/site-packages (from osfclient->uva_common==0.1.0) (1.17.0)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.12/site-packages (from pandas->uva_common==0.1.0) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas->uva_common==0.1.0) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->osfclient->uva_common==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests->osfclient->uva_common==0.1.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.12/site-packages (from requests->osfclient->uva_common==0.1.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./venv/lib/python3.12/site-packages (from requests->osfclient->uva_common==0.1.0) (2026.6.17)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import statements

# %%
import os
import uva_common
from ccc2026 import config

# %% [markdown]
# ## Create working directories if necessary

# %%
for path in [config.DATA_DIR, config.PLOT_DIR]:
    os.makedirs(path, exist_ok=True)

# %% [markdown]
# ## Download initial data

# %%
uva_common.download_all("tokens", local_dir=config.DATA_DIR)
