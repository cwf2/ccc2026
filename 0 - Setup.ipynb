# %% [markdown]
# ## Install package code and prerequisites

# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/chris/Documents/git/ccc2026
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 6.9 MB/s  0:00:017.1 MB/s eta 0:00:01:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
# Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#   Building editable for ccc2026 (pyproject.toml) ... done
#   Created wheel for ccc2026: filename=ccc2026-0.1.0-0.editable-py3-none-any.whl size=2683 sha256=c872ab85735052bafa67826dac56b36ddc23dfec27b56db5f884a8015aa9a6e5
# ...

# %% [markdown]
# ## Import statements

# %%
import os
from osfclient import OSF
from ccc2026 import config, data

# %% [markdown]
# ## Create working directories if necessary

# %%
for path in [config.DATA_DIR, config.PLOT_DIR]:
    os.makedirs(path, exist_ok=True)

# %% [markdown]
# ## Download initial data

# %%
data.download("tokens.tsv")
# Out:
# 100%|█████████████████████████████████| 64.7M/64.7M [00:06<00:00, 9.54Mbytes/s]
